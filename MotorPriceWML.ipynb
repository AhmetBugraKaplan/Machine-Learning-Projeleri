# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("motor.csv")
df
# Out:
#                                      name  ...  ex_showroom_price
# 0               Royal Enfield Classic 350  ...                NaN
# 1                               Honda Dio  ...                NaN
# 2     Royal Enfield Classic Gunmetal Grey  ...           148114.0
# 3       Yamaha Fazer FI V 2.0 [2016-2018]  ...            89643.0
# 4                   Yamaha SZ [2013-2014]  ...                NaN
# ...                                   ...  ...                ...
# 1056                            Activa 3g  ...            52000.0
# 1057                     Honda CB twister  ...            51000.0
# 1058                   Bajaj Discover 125  ...            57000.0
# 1059                       Honda CB Shine  ...            58000.0
# 1060                     Bajaj Pulsar 150  ...            75000.0
#
# [1061 rows x 7 columns]

# %%
df = df.drop(columns=["name","ex_showroom_price"])
df.head()
# Out:
#    selling_price  year seller_type      owner  km_driven
# 0         175000  2019  Individual  1st owner        350
# 1          45000  2017  Individual  1st owner       5650
# 2         150000  2018  Individual  1st owner      12000
# 3          65000  2015  Individual  1st owner      23000
# 4          20000  2011  Individual  2nd owner      21000

# %%
df.columns=["satisfiyat","yil","saticitipi","sahip","km"]
df.head(3)
# Out:
#    satisfiyat   yil  saticitipi      sahip     km
# 0      175000  2019  Individual  1st owner    350
# 1       45000  2017  Individual  1st owner   5650
# 2      150000  2018  Individual  1st owner  12000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   satisfiyat  1061 non-null   int64
#  1   yil         1061 non-null   int64
#  2   saticitipi  1061 non-null   object
#  3   sahip       1061 non-null   object
#  4   km          1061 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 41.6+ KB

# %%
df = pd.get_dummies(df,columns=["saticitipi","sahip"],drop_first=False)

# %%
df.head(3)
# Out:
#    satisfiyat   yil     km  ...  sahip_2nd owner  sahip_3rd owner  sahip_4th owner
# 0      175000  2019    350  ...            False            False            False
# 1       45000  2017   5650  ...            False            False            False
# 2      150000  2018  12000  ...            False            False            False
#
# [3 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfiyat             1061 non-null   int64
#  1   yil                    1061 non-null   int64
#  2   km                     1061 non-null   int64
#  3   saticitipi_Dealer      1061 non-null   bool
#  4   saticitipi_Individual  1061 non-null   bool
#  5   sahip_1st owner        1061 non-null   bool
#  6   sahip_2nd owner        1061 non-null   bool
#  7   sahip_3rd owner        1061 non-null   bool
#  8   sahip_4th owner        1061 non-null   bool
# dtypes: bool(6), int64(3)
# memory usage: 31.2 KB

# %%
y = df[["satisfiyat"]]
x = df.drop("satisfiyat",axis=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.70,random_state=79)

# %%
#lm = LinearRegression()
#model = lm.fit(x,y)
#model.score(x,y)

# %%
lm = LinearRegression()
model = lm.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.13109733678667757

# %%
df.head(3)
# Out:
#    satisfiyat   yil     km  ...  sahip_2nd owner  sahip_3rd owner  sahip_4th owner
# 0      175000  2019    350  ...            False            False            False
# 1       45000  2017   5650  ...            False            False            False
# 2      150000  2018  12000  ...            False            False            False
#
# [3 rows x 9 columns]

# %%
model.predict([[2016,200,1,0,1,0,0,0]])
# Out:
# array([[71151.61172803]])

# %%
df
# Out:
#       satisfiyat   yil  ...  sahip_3rd owner  sahip_4th owner
# 0         175000  2019  ...            False            False
# 1          45000  2017  ...            False            False
# 2         150000  2018  ...            False            False
# 3          65000  2015  ...            False            False
# 4          20000  2011  ...            False            False
# ...          ...   ...  ...              ...              ...
# 1056       17000  2010  ...            False            False
# 1057       16000  2012  ...            False            False
# 1058       15000  2013  ...            False            False
# 1059       12000  2009  ...            False            False
# 1060       10000  2008  ...            False            False
#
# [1061 rows x 9 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

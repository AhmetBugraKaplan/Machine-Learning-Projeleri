# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("Titanic-Dataset.csv")
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df = df.drop(columns=["PassengerId","Name","Ticket","Cabin","Age"])

# %%
df
# Out:
#      Survived  Pclass     Sex  SibSp  Parch     Fare Embarked
# 0           0       3    male      1      0   7.2500        S
# 1           1       1  female      1      0  71.2833        C
# 2           1       3  female      0      0   7.9250        S
# 3           1       1  female      1      0  53.1000        S
# 4           0       3    male      0      0   8.0500        S
# ..        ...     ...     ...    ...    ...      ...      ...
# 886         0       2    male      0      0  13.0000        S
# 887         1       1  female      0      0  30.0000        S
# 888         0       3  female      1      2  23.4500        S
# 889         1       1    male      0      0  30.0000        C
# 890         0       3    male      0      0   7.7500        Q
#
# [891 rows x 7 columns]

# %%
df = pd.get_dummies(df, "Embarked", drop_first=True,dtype=float)

# %%
df.head(3)
# Out:
#    Survived  Pclass  SibSp  Parch     Fare  Embarked_male  Embarked_Q  \
# 0         0       3      1      0   7.2500            1.0         0.0
# 1         1       1      1      0  71.2833            0.0         0.0
# 2         1       3      0      0   7.9250            0.0         0.0
#
#    Embarked_S
# 0         1.0
# 1         0.0
# 2         1.0

# %%
y = df["Survived"].astype(float)
x = df.drop(columns=["Survived"],axis=1).astype(float)

# %%
x.head(3)
# Out:
#    Pclass  SibSp  Parch     Fare  Embarked_male  Embarked_Q  Embarked_S
# 0     3.0    1.0    0.0   7.2500            1.0         0.0         1.0
# 1     1.0    1.0    0.0  71.2833            0.0         0.0         0.0
# 2     3.0    0.0    0.0   7.9250            0.0         0.0         1.0

# %%
df.info
# Out:
# <bound method DataFrame.info of      Survived  Pclass  SibSp  Parch     Fare  Embarked_male  Embarked_Q  \
# 0           0       3      1      0   7.2500            1.0         0.0
# 1           1       1      1      0  71.2833            0.0         0.0
# 2           1       3      0      0   7.9250            0.0         0.0
# 3           1       1      1      0  53.1000            0.0         0.0
# 4           0       3      0      0   8.0500            1.0         0.0
# ..        ...     ...    ...    ...      ...            ...         ...
# 886         0       2      0      0  13.0000            1.0         0.0
# 887         1       1      0      0  30.0000            0.0         0.0
# 888         0       3      1      2  23.4500            0.0         0.0
# 889         1       1      0      0  30.0000            1.0         0.0
# 890         0       3      0      0   7.7500            1.0         1.0
#
#      Embarked_S
# 0           1.0
# 1           0.0
# 2           1.0
# ...

# %%
model = Sequential()

#input layer
model.add(Dense(32,input_dim=7,activation="relu"))

#hidden layer
model.add(Dense(32,activation="relu"))
model.add(Dense(32,activation="relu"))
model.add(Dense(64,activation="relu"))

#output layer
model.add(Dense(1,activation="sigmoid"))

model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.80,random_state=7)

model.fit(x=x_train,y=y_train,epochs=32,batch_size=16,validation_split=0.2)
# Out:
# Epoch 1/32
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.5634 - loss: 0.7273 - val_accuracy: 0.5804 - val_loss: 0.6681
# Epoch 2/32
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6215 - loss: 0.6536 - val_accuracy: 0.6364 - val_loss: 0.6190
# Epoch 3/32
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6827 - loss: 0.6087 - val_accuracy: 0.6573 - val_loss: 0.6151
# Epoch 4/32
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6806 - loss: 0.5905 - val_accuracy: 0.6364 - val_loss: 0.6083
# Epoch 5/32
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6936 - loss: 0.5815 - val_accuracy: 0.6434 - val_loss: 0.5916
# Epoch 6/32
# ...

# %%
print(y.unique())
print(y.dtype)

# %%
print(x.isnull().sum())

# %%
df.head(3)
# Out:
#    Survived  Pclass  SibSp  Parch     Fare  Embarked_male  Embarked_Q  \
# 0         0       3      1      0   7.2500            1.0         0.0
# 1         1       1      1      0  71.2833            0.0         0.0
# 2         1       3      0      0   7.9250            0.0         0.0
#
#    Embarked_S
# 0         1.0
# 1         0.0
# 2         1.0

# %%
model.predict(np.array([[3.0,0.0,0.0,7.75,0.0,1.0,0.0]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# array([[0.8169151]], dtype=float32)

# %%
df.iloc[32]
# Out:
# Survived         1.00
# Pclass           3.00
# SibSp            0.00
# Parch            0.00
# Fare             7.75
# Embarked_male    0.00
# Embarked_Q       1.00
# Embarked_S       0.00
# Name: 32, dtype: float64
